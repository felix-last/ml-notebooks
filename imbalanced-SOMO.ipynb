# %% [markdown]
# # 1 Introduction

# %% [markdown]
# This notebook contains the experimental procedure in the [Self-Organizing Map Oversampling (SOMO) for imbalanced data set learning](http://www.sciencedirect.com/science/article/pii/S0957417417302324) paper.

# %% [markdown]
# # 2 Imports

# %%
from os.path import expanduser
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imbtools.evaluation import BinaryExperiment

# %% [markdown]
# # 3 Experiment

# %% [markdown]
# #### 3.1 Configure experiment

# %%
classifiers = [LogisticRegression(), GradientBoostingClassifier()]
oversampling_methods = [None, RandomOverSampler(), SMOTE(), SMOTE(kind='borderline1'), ADASYN()]
param_grids = [None, {'max_depth':[2, 3, 5, 8], 'n_estimators':[10, 50, 80, 100]}]

# %%
experiment = BinaryExperiment(expanduser('~/Main/data/somo/'), classifiers, oversampling_methods)

# %% [markdown]
# #### 3.2 Run experiment

# %%
experiment.run(logging_results=False)
# Out:
# /Users/gdouzas/Main/ve/imbalanced-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# #### 3.3 Datasets summary

# %%
experiment.datasets_summary_
# Out:
#        Dataset name  # of features  # of instances  # of minority instances  \
# 0     breast_tissue              9             106                       36
# 1             ecoli              7             336                       52
# 2        eucalyptus              8             642                       98
# 3             glass              9             214                       70
# 4          haberman              3             306                       81
# 5             heart             13             270                      120
# 6              iris              4             150                       50
# 7             libra             90             360                       72
# 8   liver_disorders              6             345                      145
# 9              pima              8             768                      268
# 10          segment             16            2310                      330
# 11          vehicle             18             846                      199
# 12             wine             13             178                       71
#
#     # of majority instances  Imbalanced Ratio
# 0                        70              1.94
# 1                       284              5.46
# 2                       544              5.55
# 3                       144              2.06
# 4                       225              2.78
# 5                       150              1.25
# 6                       100              2.00
# 7                       288              4.00
# 8                       200              1.38
# 9                       500              1.87
# 10                     1980              6.00
# 11                      647              3.25
# 12                      107              1.51

# %% [markdown]
# #### 3.4 Mean CV results

# %%
experiment.mean_cv_results_
# Out:
#            Dataset                  Classifier Oversampling method  \
# 0    breast_tissue  GradientBoostingClassifier              ADASYN
# 1    breast_tissue  GradientBoostingClassifier              ADASYN
# 2    breast_tissue  GradientBoostingClassifier              ADASYN
# 3    breast_tissue  GradientBoostingClassifier                None
# 4    breast_tissue  GradientBoostingClassifier                None
# 5    breast_tissue  GradientBoostingClassifier                None
# 6    breast_tissue  GradientBoostingClassifier   RandomOverSampler
# 7    breast_tissue  GradientBoostingClassifier   RandomOverSampler
# 8    breast_tissue  GradientBoostingClassifier   RandomOverSampler
# 9    breast_tissue  GradientBoostingClassifier               SMOTE
# 10   breast_tissue  GradientBoostingClassifier               SMOTE
# 11   breast_tissue  GradientBoostingClassifier               SMOTE
# 12   breast_tissue  GradientBoostingClassifier              SMOTE2
# 13   breast_tissue  GradientBoostingClassifier              SMOTE2
# 14   breast_tissue  GradientBoostingClassifier              SMOTE2
# 15   breast_tissue          LogisticRegression              ADASYN
# 16   breast_tissue          LogisticRegression              ADASYN
# 17   breast_tissue          LogisticRegression              ADASYN
# 18   breast_tissue          LogisticRegression                None
# 19   breast_tissue          LogisticRegression                None
# 20   breast_tissue          LogisticRegression                None
# 21   breast_tissue          LogisticRegression   RandomOverSampler
# 22   breast_tissue          LogisticRegression   RandomOverSampler
# 23   breast_tissue          LogisticRegression   RandomOverSampler
# 24   breast_tissue          LogisticRegression               SMOTE
# 25   breast_tissue          LogisticRegression               SMOTE
# 26   breast_tissue          LogisticRegression               SMOTE
# 27   breast_tissue          LogisticRegression              SMOTE2
# 28   breast_tissue          LogisticRegression              SMOTE2
# 29   breast_tissue          LogisticRegression              SMOTE2
# ..             ...                         ...                 ...
# 360           wine  GradientBoostingClassifier              ADASYN
# 361           wine  GradientBoostingClassifier              ADASYN
# 362           wine  GradientBoostingClassifier              ADASYN
# 363           wine  GradientBoostingClassifier                None
# 364           wine  GradientBoostingClassifier                None
# 365           wine  GradientBoostingClassifier                None
# 366           wine  GradientBoostingClassifier   RandomOverSampler
# 367           wine  GradientBoostingClassifier   RandomOverSampler
# 368           wine  GradientBoostingClassifier   RandomOverSampler
# 369           wine  GradientBoostingClassifier               SMOTE
# 370           wine  GradientBoostingClassifier               SMOTE
# 371           wine  GradientBoostingClassifier               SMOTE
# 372           wine  GradientBoostingClassifier              SMOTE2
# 373           wine  GradientBoostingClassifier              SMOTE2
# 374           wine  GradientBoostingClassifier              SMOTE2
# 375           wine          LogisticRegression              ADASYN
# 376           wine          LogisticRegression              ADASYN
# 377           wine          LogisticRegression              ADASYN
# 378           wine          LogisticRegression                None
# 379           wine          LogisticRegression                None
# 380           wine          LogisticRegression                None
# 381           wine          LogisticRegression   RandomOverSampler
# 382           wine          LogisticRegression   RandomOverSampler
# 383           wine          LogisticRegression   RandomOverSampler
# 384           wine          LogisticRegression               SMOTE
# 385           wine          LogisticRegression               SMOTE
# 386           wine          LogisticRegression               SMOTE
# 387           wine          LogisticRegression              SMOTE2
# 388           wine          LogisticRegression              SMOTE2
# 389           wine          LogisticRegression              SMOTE2
#
#                    Metric  Mean CV score
# 0                f1 score       0.694370
# 1    geometric mean score       0.755950
# 2           roc auc score       0.881149
# 3                f1 score       0.671965
# 4    geometric mean score       0.731175
# 5           roc auc score       0.861061
# 6                f1 score       0.660953
# 7    geometric mean score       0.739070
# 8           roc auc score       0.865972
# 9                f1 score       0.686341
# 10   geometric mean score       0.780584
# 11          roc auc score       0.859013
# 12               f1 score       0.688500
# 13   geometric mean score       0.758020
# 14          roc auc score       0.844525
# 15               f1 score       0.726577
# 16   geometric mean score       0.786767
# 17          roc auc score       0.900151
# 18               f1 score       0.682542
# 19   geometric mean score       0.748497
# 20          roc auc score       0.901550
# 21               f1 score       0.717579
# 22   geometric mean score       0.797515
# 23          roc auc score       0.896306
# 24               f1 score       0.713666
# 25   geometric mean score       0.805733
# 26          roc auc score       0.895320
# 27               f1 score       0.754933
# 28   geometric mean score       0.794134
# 29          roc auc score       0.888587
# ..                    ...            ...
# 360              f1 score       0.934542
# 361  geometric mean score       0.914606
# 362         roc auc score       0.973327
# 363              f1 score       0.910867
# 364  geometric mean score       0.922893
# 365         roc auc score       0.983994
# 366              f1 score       0.909567
# 367  geometric mean score       0.918866
# 368         roc auc score       0.981736
# 369              f1 score       0.911860
# 370  geometric mean score       0.920771
# 371         roc auc score       0.974892
# 372              f1 score       0.896612
# 373  geometric mean score       0.921795
# 374         roc auc score       0.978405
# 375              f1 score       0.915389
# 376  geometric mean score       0.941895
# 377         roc auc score       0.988591
# 378              f1 score       0.924788
# 379  geometric mean score       0.940457
# 380         roc auc score       0.991369
# 381              f1 score       0.922443
# 382  geometric mean score       0.941445
# 383         roc auc score       0.988604
# 384              f1 score       0.923240
# 385  geometric mean score       0.944137
# 386         roc auc score       0.989907
# 387              f1 score       0.930096
# 388  geometric mean score       0.943798
# 389         roc auc score       0.990093
#
# [390 rows x 5 columns]

# %% [markdown]
# #### 3.5 Standard deviation CV results

# %%
experiment.std_cv_results_
# Out:
#            Dataset                  Classifier Oversampling method  \
# 0    breast_tissue  GradientBoostingClassifier              ADASYN
# 1    breast_tissue  GradientBoostingClassifier              ADASYN
# 2    breast_tissue  GradientBoostingClassifier              ADASYN
# 3    breast_tissue  GradientBoostingClassifier                None
# 4    breast_tissue  GradientBoostingClassifier                None
# 5    breast_tissue  GradientBoostingClassifier                None
# 6    breast_tissue  GradientBoostingClassifier   RandomOverSampler
# 7    breast_tissue  GradientBoostingClassifier   RandomOverSampler
# 8    breast_tissue  GradientBoostingClassifier   RandomOverSampler
# 9    breast_tissue  GradientBoostingClassifier               SMOTE
# 10   breast_tissue  GradientBoostingClassifier               SMOTE
# 11   breast_tissue  GradientBoostingClassifier               SMOTE
# 12   breast_tissue  GradientBoostingClassifier              SMOTE2
# 13   breast_tissue  GradientBoostingClassifier              SMOTE2
# 14   breast_tissue  GradientBoostingClassifier              SMOTE2
# 15   breast_tissue          LogisticRegression              ADASYN
# 16   breast_tissue          LogisticRegression              ADASYN
# 17   breast_tissue          LogisticRegression              ADASYN
# 18   breast_tissue          LogisticRegression                None
# 19   breast_tissue          LogisticRegression                None
# 20   breast_tissue          LogisticRegression                None
# 21   breast_tissue          LogisticRegression   RandomOverSampler
# 22   breast_tissue          LogisticRegression   RandomOverSampler
# 23   breast_tissue          LogisticRegression   RandomOverSampler
# 24   breast_tissue          LogisticRegression               SMOTE
# 25   breast_tissue          LogisticRegression               SMOTE
# 26   breast_tissue          LogisticRegression               SMOTE
# 27   breast_tissue          LogisticRegression              SMOTE2
# 28   breast_tissue          LogisticRegression              SMOTE2
# 29   breast_tissue          LogisticRegression              SMOTE2
# ..             ...                         ...                 ...
# 360           wine  GradientBoostingClassifier              ADASYN
# 361           wine  GradientBoostingClassifier              ADASYN
# 362           wine  GradientBoostingClassifier              ADASYN
# 363           wine  GradientBoostingClassifier                None
# 364           wine  GradientBoostingClassifier                None
# 365           wine  GradientBoostingClassifier                None
# 366           wine  GradientBoostingClassifier   RandomOverSampler
# 367           wine  GradientBoostingClassifier   RandomOverSampler
# 368           wine  GradientBoostingClassifier   RandomOverSampler
# 369           wine  GradientBoostingClassifier               SMOTE
# 370           wine  GradientBoostingClassifier               SMOTE
# 371           wine  GradientBoostingClassifier               SMOTE
# 372           wine  GradientBoostingClassifier              SMOTE2
# 373           wine  GradientBoostingClassifier              SMOTE2
# 374           wine  GradientBoostingClassifier              SMOTE2
# 375           wine          LogisticRegression              ADASYN
# 376           wine          LogisticRegression              ADASYN
# 377           wine          LogisticRegression              ADASYN
# 378           wine          LogisticRegression                None
# 379           wine          LogisticRegression                None
# 380           wine          LogisticRegression                None
# 381           wine          LogisticRegression   RandomOverSampler
# 382           wine          LogisticRegression   RandomOverSampler
# 383           wine          LogisticRegression   RandomOverSampler
# 384           wine          LogisticRegression               SMOTE
# 385           wine          LogisticRegression               SMOTE
# 386           wine          LogisticRegression               SMOTE
# 387           wine          LogisticRegression              SMOTE2
# 388           wine          LogisticRegression              SMOTE2
# 389           wine          LogisticRegression              SMOTE2
#
#                    Metric  Std CV score
# 0                f1 score      0.035976
# 1    geometric mean score      0.039353
# 2           roc auc score      0.028755
# 3                f1 score      0.022996
# 4    geometric mean score      0.044824
# 5           roc auc score      0.017276
# 6                f1 score      0.028659
# 7    geometric mean score      0.029337
# 8           roc auc score      0.010915
# 9                f1 score      0.030207
# 10   geometric mean score      0.043302
# 11          roc auc score      0.019217
# 12               f1 score      0.040990
# 13   geometric mean score      0.031942
# 14          roc auc score      0.021788
# 15               f1 score      0.028793
# 16   geometric mean score      0.029284
# 17          roc auc score      0.010548
# 18               f1 score      0.044539
# 19   geometric mean score      0.034492
# 20          roc auc score      0.022742
# 21               f1 score      0.029031
# 22   geometric mean score      0.024131
# 23          roc auc score      0.014132
# 24               f1 score      0.030996
# 25   geometric mean score      0.024757
# 26          roc auc score      0.011344
# 27               f1 score      0.023698
# 28   geometric mean score      0.022519
# 29          roc auc score      0.011176
# ..                    ...           ...
# 360              f1 score      0.036185
# 361  geometric mean score      0.017967
# 362         roc auc score      0.011072
# 363              f1 score      0.022098
# 364  geometric mean score      0.017090
# 365         roc auc score      0.006490
# 366              f1 score      0.015309
# 367  geometric mean score      0.009394
# 368         roc auc score      0.010580
# 369              f1 score      0.005104
# 370  geometric mean score      0.010759
# 371         roc auc score      0.016230
# 372              f1 score      0.018980
# 373  geometric mean score      0.010588
# 374         roc auc score      0.009567
# 375              f1 score      0.016052
# 376  geometric mean score      0.012964
# 377         roc auc score      0.003759
# 378              f1 score      0.007274
# 379  geometric mean score      0.004660
# 380         roc auc score      0.003028
# 381              f1 score      0.007394
# 382  geometric mean score      0.009277
# 383         roc auc score      0.002009
# 384              f1 score      0.018535
# 385  geometric mean score      0.012664
# 386         roc auc score      0.002748
# 387              f1 score      0.007892
# 388  geometric mean score      0.008708
# 389         roc auc score      0.002775
#
# [390 rows x 5 columns]

# %% [markdown]
# #### 3.6. Oversampling methods mean ranking

# %%
experiment.mean_ranking_results_
# Out:
#                                                  ADASYN  None  \
# Classifier                 Metric
# GradientBoostingClassifier f1 score                2.69  3.69
#                            geometric mean score    3.00  4.15
#                            roc auc score           3.08  2.62
# LogisticRegression         f1 score                3.46  4.15
#                            geometric mean score    3.46  4.69
#                            roc auc score           3.38  2.77
#
#                                                  RandomOverSampler  SMOTE  \
# Classifier                 Metric
# GradientBoostingClassifier f1 score                           3.31   2.38
#                            geometric mean score               2.85   2.46
#                            roc auc score                      2.85   3.38
# LogisticRegression         f1 score                           2.77   2.31
#                            geometric mean score               2.62   1.92
#                            roc auc score                      2.77   2.23
#
#                                                  SMOTE2
# Classifier                 Metric
# GradientBoostingClassifier f1 score                2.92
#                            geometric mean score    2.54
#                            roc auc score           3.08
# LogisticRegression         f1 score                2.31
#                            geometric mean score    2.31
#                            roc auc score           3.85

# %% [markdown]
# #### 3.7 Friedman test

# %%
experiment.friedman_test_results_
# Out:
#                                                   p-value
# Classifier                 Metric
# GradientBoostingClassifier f1 score              0.241765
#                            geometric mean score  0.046532
#                            roc auc score         0.786522
# LogisticRegression         f1 score              0.009932
#                            geometric mean score  0.000044
#                            roc auc score         0.087172

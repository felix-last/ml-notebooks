# %% [markdown]
# # 1 Introduction

# %% [markdown]
# This notebook contains the experimental procedure in the [Self-Organizing Map Oversampling (SOMO) for imbalanced data set learning](http://www.sciencedirect.com/science/article/pii/S0957417417302324) paper.

# %% [markdown]
# # 2 Imports

# %%
from os.path import expanduser
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imbtools.evaluation import BinaryExperiment

# %% [markdown]
# # 3 Experiment

# %% [markdown]
# #### 3.1 Configure experiment

# %%
classifiers = [LogisticRegression(), GradientBoostingClassifier()]
oversampling_methods = [None, RandomOverSampler(), SMOTE(), SMOTE(kind='borderline1'), ADASYN()]
param_grids = [None, {'max_depth':[2, 3, 5, 8], 'n_estimators':[10, 50, 80, 100]}]

# %%
experiment = BinaryExperiment(expanduser('~/Main/data/somo/'), classifiers, oversampling_methods, param_grids=param_grids)

# %% [markdown]
# #### 3.2 Run experiment

# %%
experiment.run(logging_results=False)

# %% [markdown]
# #### 3.3 Datasets summary

# %%
experiment.datasets_summary_
# Out:
#        Dataset name  # of features  # of instances  # of minority instances  \
# 0     breast_tissue              9             106                       36
# 1             ecoli              7             336                       52
# 2        eucalyptus              8             642                       98
# 3             glass              9             214                       70
# 4          haberman              3             306                       81
# 5             heart             13             270                      120
# 6              iris              4             150                       50
# 7             libra             90             360                       72
# 8   liver_disorders              6             345                      145
# 9              pima              8             768                      268
# 10          segment             16            2310                      330
# 11          vehicle             18             846                      199
# 12             wine             13             178                       71
#
#     # of majority instances  Imbalanced Ratio
# 0                        70              1.94
# 1                       284              5.46
# 2                       544              5.55
# 3                       144              2.06
# 4                       225              2.78
# 5                       150              1.25
# 6                       100              2.00
# 7                       288              4.00
# 8                       200              1.38
# 9                       500              1.87
# 10                     1980              6.00
# 11                      647              3.25
# 12                      107              1.51

# %% [markdown]
# #### 3.4 Mean CV results

# %%
experiment.mean_cv_results_
# Out:
#            Dataset                  Classifier Oversampling method  \
# 0    breast_tissue  GradientBoostingClassifier              ADASYN
# 1    breast_tissue  GradientBoostingClassifier              ADASYN
# 2    breast_tissue  GradientBoostingClassifier              ADASYN
# 3    breast_tissue  GradientBoostingClassifier                None
# 4    breast_tissue  GradientBoostingClassifier                None
# 5    breast_tissue  GradientBoostingClassifier                None
# 6    breast_tissue  GradientBoostingClassifier   RandomOverSampler
# 7    breast_tissue  GradientBoostingClassifier   RandomOverSampler
# 8    breast_tissue  GradientBoostingClassifier   RandomOverSampler
# 9    breast_tissue  GradientBoostingClassifier               SMOTE
# 10   breast_tissue  GradientBoostingClassifier               SMOTE
# 11   breast_tissue  GradientBoostingClassifier               SMOTE
# 12   breast_tissue  GradientBoostingClassifier              SMOTE2
# 13   breast_tissue  GradientBoostingClassifier              SMOTE2
# 14   breast_tissue  GradientBoostingClassifier              SMOTE2
# 15   breast_tissue          LogisticRegression              ADASYN
# 16   breast_tissue          LogisticRegression              ADASYN
# 17   breast_tissue          LogisticRegression              ADASYN
# 18   breast_tissue          LogisticRegression                None
# 19   breast_tissue          LogisticRegression                None
# 20   breast_tissue          LogisticRegression                None
# 21   breast_tissue          LogisticRegression   RandomOverSampler
# 22   breast_tissue          LogisticRegression   RandomOverSampler
# 23   breast_tissue          LogisticRegression   RandomOverSampler
# 24   breast_tissue          LogisticRegression               SMOTE
# 25   breast_tissue          LogisticRegression               SMOTE
# 26   breast_tissue          LogisticRegression               SMOTE
# 27   breast_tissue          LogisticRegression              SMOTE2
# 28   breast_tissue          LogisticRegression              SMOTE2
# 29   breast_tissue          LogisticRegression              SMOTE2
# ..             ...                         ...                 ...
# 360           wine  GradientBoostingClassifier              ADASYN
# 361           wine  GradientBoostingClassifier              ADASYN
# 362           wine  GradientBoostingClassifier              ADASYN
# 363           wine  GradientBoostingClassifier                None
# 364           wine  GradientBoostingClassifier                None
# 365           wine  GradientBoostingClassifier                None
# 366           wine  GradientBoostingClassifier   RandomOverSampler
# 367           wine  GradientBoostingClassifier   RandomOverSampler
# 368           wine  GradientBoostingClassifier   RandomOverSampler
# 369           wine  GradientBoostingClassifier               SMOTE
# 370           wine  GradientBoostingClassifier               SMOTE
# 371           wine  GradientBoostingClassifier               SMOTE
# 372           wine  GradientBoostingClassifier              SMOTE2
# 373           wine  GradientBoostingClassifier              SMOTE2
# 374           wine  GradientBoostingClassifier              SMOTE2
# 375           wine          LogisticRegression              ADASYN
# 376           wine          LogisticRegression              ADASYN
# 377           wine          LogisticRegression              ADASYN
# 378           wine          LogisticRegression                None
# 379           wine          LogisticRegression                None
# 380           wine          LogisticRegression                None
# 381           wine          LogisticRegression   RandomOverSampler
# 382           wine          LogisticRegression   RandomOverSampler
# 383           wine          LogisticRegression   RandomOverSampler
# 384           wine          LogisticRegression               SMOTE
# 385           wine          LogisticRegression               SMOTE
# 386           wine          LogisticRegression               SMOTE
# 387           wine          LogisticRegression              SMOTE2
# 388           wine          LogisticRegression              SMOTE2
# 389           wine          LogisticRegression              SMOTE2
#
#                    Metric  Mean CV score
# 0                f1 score       0.657800
# 1    geometric mean score       0.781593
# 2           roc auc score       0.882221
# 3                f1 score       0.670899
# 4    geometric mean score       0.748598
# 5           roc auc score       0.872977
# 6                f1 score       0.678395
# 7    geometric mean score       0.752401
# 8           roc auc score       0.861735
# 9                f1 score       0.678735
# 10   geometric mean score       0.766667
# 11          roc auc score       0.873908
# 12               f1 score       0.668636
# 13   geometric mean score       0.722779
# 14          roc auc score       0.845295
# 15               f1 score       0.718079
# 16   geometric mean score       0.800392
# 17          roc auc score       0.899477
# 18               f1 score       0.672981
# 19   geometric mean score       0.762883
# 20          roc auc score       0.900151
# 21               f1 score       0.731533
# 22   geometric mean score       0.792845
# 23          roc auc score       0.896618
# 24               f1 score       0.737931
# 25   geometric mean score       0.786788
# 26          roc auc score       0.896276
# 27               f1 score       0.732014
# 28   geometric mean score       0.792297
# 29          roc auc score       0.897494
# ..                    ...            ...
# 360              f1 score       0.922515
# 361  geometric mean score       0.920463
# 362         roc auc score       0.987203
# 363              f1 score       0.922381
# 364  geometric mean score       0.923100
# 365         roc auc score       0.987203
# 366              f1 score       0.923060
# 367  geometric mean score       0.953213
# 368         roc auc score       0.988468
# 369              f1 score       0.941169
# 370  geometric mean score       0.938492
# 371         roc auc score       0.986121
# 372              f1 score       0.909456
# 373  geometric mean score       0.934547
# 374         roc auc score       0.990707
# 375              f1 score       0.928730
# 376  geometric mean score       0.941187
# 377         roc auc score       0.990108
# 378              f1 score       0.925989
# 379  geometric mean score       0.938514
# 380         roc auc score       0.989344
# 381              f1 score       0.928636
# 382  geometric mean score       0.937954
# 383         roc auc score       0.986831
# 384              f1 score       0.930361
# 385  geometric mean score       0.943245
# 386         roc auc score       0.990963
# 387              f1 score       0.935707
# 388  geometric mean score       0.945740
# 389         roc auc score       0.990161
#
# [390 rows x 5 columns]

# %% [markdown]
# #### 3.5 Standard deviation CV results

# %%
experiment.std_cv_results_
# Out:
#            Dataset                  Classifier Oversampling method  \
# 0    breast_tissue  GradientBoostingClassifier              ADASYN
# 1    breast_tissue  GradientBoostingClassifier              ADASYN
# 2    breast_tissue  GradientBoostingClassifier              ADASYN
# 3    breast_tissue  GradientBoostingClassifier                None
# 4    breast_tissue  GradientBoostingClassifier                None
# 5    breast_tissue  GradientBoostingClassifier                None
# 6    breast_tissue  GradientBoostingClassifier   RandomOverSampler
# 7    breast_tissue  GradientBoostingClassifier   RandomOverSampler
# 8    breast_tissue  GradientBoostingClassifier   RandomOverSampler
# 9    breast_tissue  GradientBoostingClassifier               SMOTE
# 10   breast_tissue  GradientBoostingClassifier               SMOTE
# 11   breast_tissue  GradientBoostingClassifier               SMOTE
# 12   breast_tissue  GradientBoostingClassifier              SMOTE2
# 13   breast_tissue  GradientBoostingClassifier              SMOTE2
# 14   breast_tissue  GradientBoostingClassifier              SMOTE2
# 15   breast_tissue          LogisticRegression              ADASYN
# 16   breast_tissue          LogisticRegression              ADASYN
# 17   breast_tissue          LogisticRegression              ADASYN
# 18   breast_tissue          LogisticRegression                None
# 19   breast_tissue          LogisticRegression                None
# 20   breast_tissue          LogisticRegression                None
# 21   breast_tissue          LogisticRegression   RandomOverSampler
# 22   breast_tissue          LogisticRegression   RandomOverSampler
# 23   breast_tissue          LogisticRegression   RandomOverSampler
# 24   breast_tissue          LogisticRegression               SMOTE
# 25   breast_tissue          LogisticRegression               SMOTE
# 26   breast_tissue          LogisticRegression               SMOTE
# 27   breast_tissue          LogisticRegression              SMOTE2
# 28   breast_tissue          LogisticRegression              SMOTE2
# 29   breast_tissue          LogisticRegression              SMOTE2
# ..             ...                         ...                 ...
# 360           wine  GradientBoostingClassifier              ADASYN
# 361           wine  GradientBoostingClassifier              ADASYN
# 362           wine  GradientBoostingClassifier              ADASYN
# 363           wine  GradientBoostingClassifier                None
# 364           wine  GradientBoostingClassifier                None
# 365           wine  GradientBoostingClassifier                None
# 366           wine  GradientBoostingClassifier   RandomOverSampler
# 367           wine  GradientBoostingClassifier   RandomOverSampler
# 368           wine  GradientBoostingClassifier   RandomOverSampler
# 369           wine  GradientBoostingClassifier               SMOTE
# 370           wine  GradientBoostingClassifier               SMOTE
# 371           wine  GradientBoostingClassifier               SMOTE
# 372           wine  GradientBoostingClassifier              SMOTE2
# 373           wine  GradientBoostingClassifier              SMOTE2
# 374           wine  GradientBoostingClassifier              SMOTE2
# 375           wine          LogisticRegression              ADASYN
# 376           wine          LogisticRegression              ADASYN
# 377           wine          LogisticRegression              ADASYN
# 378           wine          LogisticRegression                None
# 379           wine          LogisticRegression                None
# 380           wine          LogisticRegression                None
# 381           wine          LogisticRegression   RandomOverSampler
# 382           wine          LogisticRegression   RandomOverSampler
# 383           wine          LogisticRegression   RandomOverSampler
# 384           wine          LogisticRegression               SMOTE
# 385           wine          LogisticRegression               SMOTE
# 386           wine          LogisticRegression               SMOTE
# 387           wine          LogisticRegression              SMOTE2
# 388           wine          LogisticRegression              SMOTE2
# 389           wine          LogisticRegression              SMOTE2
#
#                    Metric  Std CV score
# 0                f1 score      0.034889
# 1    geometric mean score      0.027785
# 2           roc auc score      0.012075
# 3                f1 score      0.042172
# 4    geometric mean score      0.054539
# 5           roc auc score      0.028788
# 6                f1 score      0.036864
# 7    geometric mean score      0.029109
# 8           roc auc score      0.017731
# 9                f1 score      0.044691
# 10   geometric mean score      0.038225
# 11          roc auc score      0.026799
# 12               f1 score      0.023975
# 13   geometric mean score      0.027859
# 14          roc auc score      0.047142
# 15               f1 score      0.029195
# 16   geometric mean score      0.031567
# 17          roc auc score      0.023514
# 18               f1 score      0.074497
# 19   geometric mean score      0.035930
# 20          roc auc score      0.023608
# 21               f1 score      0.037068
# 22   geometric mean score      0.027683
# 23          roc auc score      0.014274
# 24               f1 score      0.049068
# 25   geometric mean score      0.012854
# 26          roc auc score      0.007822
# 27               f1 score      0.045715
# 28   geometric mean score      0.020168
# 29          roc auc score      0.011118
# ..                    ...           ...
# 360              f1 score      0.026587
# 361  geometric mean score      0.020201
# 362         roc auc score      0.008314
# 363              f1 score      0.021093
# 364  geometric mean score      0.021500
# 365         roc auc score      0.011149
# 366              f1 score      0.025420
# 367  geometric mean score      0.015946
# 368         roc auc score      0.007179
# 369              f1 score      0.017475
# 370  geometric mean score      0.015153
# 371         roc auc score      0.008362
# 372              f1 score      0.030747
# 373  geometric mean score      0.014724
# 374         roc auc score      0.005797
# 375              f1 score      0.011898
# 376  geometric mean score      0.014834
# 377         roc auc score      0.002317
# 378              f1 score      0.009602
# 379  geometric mean score      0.015229
# 380         roc auc score      0.003353
# 381              f1 score      0.004722
# 382  geometric mean score      0.011874
# 383         roc auc score      0.005594
# 384              f1 score      0.010748
# 385  geometric mean score      0.008822
# 386         roc auc score      0.002795
# 387              f1 score      0.008414
# 388  geometric mean score      0.009790
# 389         roc auc score      0.002262
#
# [390 rows x 5 columns]

# %% [markdown]
# #### 3.6. Oversampling methods mean ranking

# %%
experiment.mean_ranking_results_
# Out:
#                                                  ADASYN  None  \
# Classifier                 Metric
# GradientBoostingClassifier f1 score                3.31  4.00
#                            geometric mean score    2.08  4.38
#                            roc auc score           3.31  2.69
# LogisticRegression         f1 score                3.62  4.31
#                            geometric mean score    2.69  4.46
#                            roc auc score           2.92  2.46
#
#                                                  RandomOverSampler  SMOTE  \
# Classifier                 Metric
# GradientBoostingClassifier f1 score                           2.62   2.54
#                            geometric mean score               2.69   2.46
#                            roc auc score                      2.69   3.00
# LogisticRegression         f1 score                           2.69   1.77
#                            geometric mean score               2.46   2.69
#                            roc auc score                      3.23   2.62
#
#                                                  SMOTE2
# Classifier                 Metric
# GradientBoostingClassifier f1 score                2.54
#                            geometric mean score    3.38
#                            roc auc score           3.31
# LogisticRegression         f1 score                2.62
#                            geometric mean score    2.69
#                            roc auc score           3.77

# %% [markdown]
# #### 3.7 Friedman test

# %%
experiment.friedman_test_results_
# Out:
#                                                   p-value
# Classifier                 Metric
# GradientBoostingClassifier f1 score              0.069702
#                            geometric mean score  0.001792
#                            roc auc score         0.741418
# LogisticRegression         f1 score              0.000499
#                            geometric mean score  0.007006
#                            roc auc score         0.225891
